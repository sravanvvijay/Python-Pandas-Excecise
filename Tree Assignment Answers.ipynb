# %%
import os
import pandas as pd

data_dir="C://Users/573380/Documents/Assignments"
os.chdir(data_dir)

# %%
data=pd.read_json("amsterdam.json")

# %%
1. #how many rows in the raw dataset
data.count()
# Out:
# host_listings_count               15178
# accommodates                      15181
# bathrooms                         15163
# bedrooms                          15169
# guests_included                   15181
# minimum_nights                    15181
# number_of_reviews                 15181
# calculated_host_listings_count    15181
# price                             15181
# latitude                          15181
# longitude                         15181
# room_type                         15181
# instant_bookable                  15181
# dtype: int64

# %%
2. #is the column "Bathroom" in the data
# Out:
# 2.0

# %%
3. # cloumn "bedrooms" has 12 missing values
# Out:
# 3.0

# %%
4. #the variable lattitude is a numeric variable that you just read in
data['latitude'].describe()
# Out:
# count    15181.000000
# mean        52.365353
# std          0.015738
# min         52.290308
# 25%         52.355616
# 50%         52.365028
# 75%         52.374829
# max         52.426224
# Name: latitude, dtype: float64

# %%
5. #the average value of price cloumns
data['price']=data['price'].str.replace('$', '')

# %%
data['price']=data['price'].str.replace(',', '')

# %%
data.price=pd.to_numeric(data.price)

# %%
round(data.price.mean(),3)
# Out:
# 134.799

# %%
6. # the maximum value in the price column is
round(data.price.max(),1)
# Out:
# 3142.0

# %%
7. #what is the 99th percentile of price column is
data['price'].quantile(0.99)
# Out:
# 440.0

# %%
8. #remove all the rows where the price column more than 440,what is the 90th percentile now
price440=data[data['price']<=440.0]

# %%
price440.quantile(0.90)
# Out:
# host_listings_count                 3.000000
# accommodates                        4.000000
# bathrooms                           1.500000
# bedrooms                            2.000000
# guests_included                     2.000000
# minimum_nights                      4.000000
# number_of_reviews                  43.000000
# calculated_host_listings_count      3.000000
# price                             210.000000
# latitude                           52.383550
# longitude                           4.934756
# Name: 0.9, dtype: float64

# %%
9. #drop all the missing values in the data and how many rows left
data_miss=data.dropna(axis = 0, how ='any')

# %%
data_miss.count()
# Out:
# host_listings_count               15148
# accommodates                      15148
# bathrooms                         15148
# bedrooms                          15148
# guests_included                   15148
# minimum_nights                    15148
# number_of_reviews                 15148
# calculated_host_listings_count    15148
# price                             15148
# latitude                          15148
# longitude                         15148
# room_type                         15148
# instant_bookable                  15148
# dtype: int64

# %%
10. # find the distance function and find 2nd price from sort ascending order
from math import radians, cos, sin, asin, sqrt
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    km = 6367 * c
    return km


for index, row in data.iterrows():
    a_longitude = 4.899431
    a_latitude  = 52.379189
    data.loc[index,'d_center'] = haversine(row['longitude'],row['latitude'],a_longitude, a_latitude)

# %%
data.sort_values("d_center")
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 3158                  1.0             2        1.5       1.0                1
# 3168                  1.0             4        1.0       1.0                1
# 2639                  1.0             4        1.0       1.0                2
# 3010                  4.0             2        1.0       1.0                1
# 1860                  1.0             2        1.0       1.0                1
# 1447                  4.0             2        1.0       1.0                1
# 3064                  2.0             2        1.0       1.0                1
# 1660                  1.0             2        1.0       1.0                1
# 1481                  1.0             2        1.0       1.0                1
# 1939                  1.0             4        1.0       1.0                2
# 2536                  3.0             4        1.0       1.0                1
# 2180                  2.0             5        1.0       2.0                4
# 2956                  2.0             2        2.0       1.0                1
# 2439                  1.0             3        1.0       1.0                1
# 3025                  3.0             3        1.0       1.0                2
# 3056                  1.0             2        1.0       1.0                1
# 2048                  1.0             4        1.5       2.0                2
# 2413                 29.0             4        1.0       0.0                1
# 2491                  1.0             2        1.0       1.0                1
# 2997                  1.0             4        1.0       2.0                1
# 3131                  1.0             2        1.0       1.0                1
# 2137                  2.0             4        0.5       2.0                2
# 1585                  4.0             2        1.0       1.0                1
# 2616                  2.0             4        0.5       0.0                2
# 1596                  1.0             5        1.5       0.0                1
# 3181                  1.0             3        1.0       2.0                1
# 2255                  1.0             2        1.0       1.0                1
# 2594                  4.0             2        1.0       1.0                1
# 2825                  1.0             3        1.0       1.0                2
# 2854                  1.0             2        1.5       1.0                1
# ...                   ...           ...        ...       ...              ...
# 6746                  2.0             2        1.0       1.0                1
# 6808                  2.0             2        1.0       1.0                2
# 6778                  1.0             5        1.0       2.0                4
# 6800                  1.0             2        1.0       1.0                2
# 6810                  1.0             2        1.0       1.0                1
# 6737                  2.0             3        1.0       1.0                2
# 6769                  1.0             3        1.0       1.0                2
# 6773                  1.0             2        1.0       1.0                1
# 6784                  1.0             2        1.0       1.0                1
# 6755                  3.0             2        1.5       1.0                1
# 6788                  1.0             4        1.0       3.0                6
# 6790                  2.0             2        1.0       1.0                2
# 6796                  3.0             6        1.5       3.0                7
# 6802                  3.0             2        1.0       1.0                1
# 6803                  3.0             2        1.5       1.0                2
# 6748                  3.0             2        1.5       1.0                1
# 6774                  3.0             2        1.0       1.0                1
# 6758                  2.0             2        1.0       1.0                1
# 6805                  1.0             4        1.5       1.0                2
# 6767                  2.0             2        2.0       1.0                1
# 6782                  2.0             1        2.0       1.0                1
# 6801                  1.0             3        1.5       1.0                2
# 6759                  1.0             3        1.0       1.0                1
# 6786                  1.0             3        1.0       1.0                2
# 6797                  1.0             1        1.0       1.0                1
# 6804                  1.0             3        1.0       1.0                2
# 6779                  1.0             4        1.0       3.0                1
# 6791                  1.0             2        1.0       1.0                1
# 6766                  1.0             2        1.0       1.0                1
# 6764                  1.0             3        1.0       3.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 3158               1                  0                               1
# 3168               1                  0                               1
# 2639               3                 27                               1
# 3010               1                  4                               4
# 1860               1                  9                               1
# 1447               1                  0                               4
# 3064               2                 21                               1
# 1660               3                  0                               1
# 1481               6                  0                               1
# 1939               2                  8                               1
# 2536               3                  6                               3
# 2180               3                  1                               2
# 2956               1                 82                               2
# 2439               2                  2                               1
# 3025               2                  1                               2
# 3056               2                  0                               1
# 2048               1                 15                               1
# 2413               3                  0                              28
# 2491               3                 36                               1
# 2997               2                  3                               1
# 3131               1                 26                               1
# 2137               1                  1                               2
# 1585               1                  0                               4
# 2616               1                  3                               2
# 1596               2                  2                               1
# 3181               7                  0                               1
# 2255               3                  6                               1
# 2594               1                  0                               4
# 2825               1                  2                               1
# 2854               4                  0                               1
# ...              ...                ...                             ...
# 6746               1                  3                               2
# 6808               2                 67                               2
# 6778               2                 13                               1
# 6800               1                  5                               1
# 6810               2                 18                               1
# 6737               2                 78                               2
# 6769               3                 44                               1
# 6773               2                  5                               1
# 6784               1                  1                               1
# 6755               1                  0                               3
# 6788               2                 16                               1
# 6790               1                 57                               2
# 6796               2                  0                               3
# 6802               2                  8                               3
# 6803               1                  8                               3
# 6748               1                 29                               3
# 6774               2                  1                               3
# 6758               2                 94                               2
# 6805               1                 17                               1
# 6767               1                  2                               2
# 6782               1                  2                               2
# 6801               1                  0                               1
# 6759               1                  0                               1
# 6786               2                  3                               1
# 6797               1                 44                               1
# 6804               2                 37                               1
# 6779               3                  1                               1
# 6791               1                 22                               1
# 6766               2                  5                               1
# 6764              30                  0                               1
#
#       price   latitude  longitude        room_type instant_bookable   d_center
# 3158   85.0  52.378546   4.900775     Private room                f   0.115801
# 3168   41.0  52.378850   4.901433      Shared room                f   0.140946
# 2639  159.0  52.379089   4.897293  Entire home/apt                f   0.145468
# 3010  150.0  52.378549   4.896679     Private room                t   0.199767
# 1860  120.0  52.378398   4.896674     Private room                f   0.206638
# 1447  250.0  52.377927   4.897073     Private room                f   0.212781
# 3064  150.0  52.378273   4.896626  Entire home/apt                t   0.215779
# 1660  200.0  52.377718   4.897159  Entire home/apt                f   0.224711
# 1481  130.0  52.378475   4.896224  Entire home/apt                t   0.231548
# 1939  145.0  52.378837   4.895983  Entire home/apt                t   0.237135
# 2536  175.0  52.377187   4.898136      Shared room                t   0.239143
# 2180  260.0  52.377586   4.901892  Entire home/apt                f   0.244084
# 2956   44.0  52.381392   4.899658     Private room                t   0.245291
# 2439  150.0  52.377078   4.897727  Entire home/apt                f   0.261459
# 3025  149.0  52.377324   4.897056  Entire home/apt                f   0.262547
# 3056  130.0  52.376807   4.899917  Entire home/apt                f   0.266703
# 2048  138.0  52.377653   4.896400  Entire home/apt                f   0.267255
# 2413  169.0  52.377522   4.896530  Entire home/apt                f   0.270236
# 2491  130.0  52.377774   4.896102  Entire home/apt                f   0.275184
# 2997  250.0  52.377229   4.896887  Entire home/apt                t   0.277847
# 3131   95.0  52.376689   4.899255  Entire home/apt                t   0.278080
# 2137  141.0  52.380980   4.902345  Entire home/apt                t   0.280462
# 1585  150.0  52.378612   4.895389     Private room                f   0.281578
# 2616   81.0  52.381672   4.900275  Entire home/apt                t   0.281758
# 1596  180.0  52.377623   4.902706  Entire home/apt                f   0.282204
# 3181  160.0  52.377614   4.895961  Entire home/apt                f   0.293360
# 2255  130.0  52.376591   4.900877  Entire home/apt                f   0.304958
# 2594  150.0  52.378099   4.895268     Private room                f   0.307260
# 2825   90.0  52.378947   4.894908     Private room                t   0.308009
# 2854  125.0  52.379128   4.894884  Entire home/apt                f   0.308551
# ...     ...        ...        ...              ...              ...        ...
# 6746   50.0  52.299211   4.987568     Private room                f  10.714388
# 6808   45.0  52.299802   4.989116     Private room                f  10.719309
# 6778  119.0  52.292869   4.969895  Entire home/apt                f  10.719331
# 6800   25.0  52.297740   4.984039     Private room                f  10.720158
# 6810   93.0  52.298288   4.985535  Entire home/apt                f  10.723793
# 6737   31.0  52.299510   4.988670     Private room                f  10.728928
# 6769   60.0  52.299451   4.988602     Private room                f  10.731770
# 6773   65.0  52.294460   4.975906  Entire home/apt                t  10.752446
# 6784  100.0  52.292888   4.972911     Private room                f  10.810483
# 6755   50.0  52.302070   4.997182     Private room                t  10.839239
# 6788  175.0  52.299875   4.994068  Entire home/apt                f  10.907298
# 6790   50.0  52.300856   4.996407     Private room                t  10.914329
# 6796  175.0  52.301257   4.997532  Entire home/apt                t  10.925213
# 6802   55.0  52.299241   4.993944     Private room                f  10.959422
# 6803   75.0  52.300915   4.997996     Private room                f  10.974666
# 6748   47.0  52.300351   4.997291     Private room                t  10.995390
# 6774   75.0  52.300130   4.998557     Private room                f  11.066966
# 6758   50.0  52.299685   4.997847     Private room                t  11.077151
# 6805   60.0  52.305976   5.010771     Private room                f  11.105292
# 6767   80.0  52.297166   4.993197     Private room                f  11.118057
# 6782   60.0  52.297613   4.994682     Private room                f  11.135626
# 6801   65.0  52.296297   4.992101     Private room                f  11.155282
# 6759   84.0  52.290308   4.978471     Private room                f  11.240968
# 6786   35.0  52.291462   4.982388     Private room                f  11.259013
# 6797   38.0  52.298440   5.000180     Private room                t  11.283228
# 6804   40.0  52.290687   4.983784     Private room                f  11.381113
# 6779  101.0  52.292209   4.989963  Entire home/apt                f  11.454847
# 6791   50.0  52.292890   4.995102     Private room                t  11.583068
# 6766   50.0  52.291664   4.992333     Private room                f  11.592780
# 6764   83.0  52.302752   5.020968  Entire home/apt                f  11.842162
#
# [15181 rows x 14 columns]

# %%
data_miss.head()
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                     1.0             6        1.0       2.0                1
# 1                     1.0             2        1.0       1.0                1
# 10                    1.0             2        1.0       1.0                1
# 100                   1.0             5        1.0       4.0                1
# 1000                  1.0             1        1.0       1.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 0                  3                  4                               1
# 1                  2                 17                               1
# 10                 3                  0                               1
# 100                5                  2                               1
# 1000               1                 32                               1
#
#       price   latitude  longitude        room_type instant_bookable  d_center
# 0     145.0  52.361173   4.866755  Entire home/apt                f  2.987199
# 1      88.0  52.370237   4.859507  Entire home/apt                f  2.885443
# 10    130.0  52.371424   4.848644  Entire home/apt                f  3.551815
# 100    90.0  52.312889   4.980151  Entire home/apt                f  9.181975
# 1000   39.0  52.395334   4.916701     Private room                t  2.142603
